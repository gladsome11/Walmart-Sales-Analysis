# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WalmartSalesData.csv.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df['Day']= df['Date'].dt.day_name()

# %%
df['Month']= df['Date'].dt.month

# %%
month_name = {1:'January',2:'February',3:'March'}
df['Month']= df['Month'].map(month_name)

# %%
highest_price =df['Unit price'].max()
goods =df[df['Unit price']== highest_price]
goods
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 122  219-22-9386      B   Mandalay        Member   Male  Sports and travel
# 983  148-41-7930      C  Naypyitaw        Normal   Male  Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date      Time      Payment  \
# 122       99.96         9  44.982  944.622 2019-03-09  17:26:00  Credit card
# 983       99.96         7  34.986  734.706 2019-01-23  10:33:00         Cash
#
#        cogs  gross margin percentage  gross income  Rating        Day    Month
# 122  899.64                 4.761905        44.982     4.2   Saturday    March
# 983  699.72                 4.761905        34.986     6.1  Wednesday  January

# %%
highest_cogs =df['cogs'].max()
revenue =df[df['cogs']== highest_cogs]
revenue
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date      Time      Payment  \
# 350        99.3        10   49.65  1042.65 2019-02-15  14:53:00  Credit card
#
#       cogs  gross margin percentage  gross income  Rating     Day     Month
# 350  993.0                 4.761905         49.65     6.6  Friday  February

# %%
highest_quantity =df['Quantity'].max()
Quantity =df[df['Quantity']== highest_quantity]
Quantity.head(10)
# Out:
#      Invoice ID Branch       City Customer type  Gender         Product line  \
# 7   315-22-5665      C  Naypyitaw        Normal  Female   Home and lifestyle
# 13  252-56-2699      A     Yangon        Normal    Male   Food and beverages
# 14  829-34-3910      A     Yangon        Normal  Female    Health and beauty
# 49  574-22-5561      C  Naypyitaw        Member  Female  Fashion accessories
# 58  817-48-8732      A     Yangon        Member  Female   Home and lifestyle
# 63  199-75-8169      A     Yangon        Member    Male    Sports and travel
# 65  877-22-3308      A     Yangon        Member    Male    Health and beauty
# 68  232-11-3025      A     Yangon        Normal    Male    Sports and travel
# 70  393-65-2792      C  Naypyitaw        Normal    Male   Food and beverages
# 71  796-12-2025      C  Naypyitaw        Normal    Male  Fashion accessories
#
#     Unit price  Quantity  Tax 5%    Total       Date      Time      Payment  \
# ...

# %% [markdown]
# # Sales Performance

# %% [markdown]
# ## What branch generate the most revenue?

# %%
 grp = df.groupby(['Branch','Product line']).agg({'Total':'sum','Quantity':'sum',})

# %%
grp
# Out:
#                                     Total  Quantity
# Branch Product line
# A      Electronic accessories  18317.1135       322
#        Fashion accessories     16332.5085       263
#        Food and beverages      17163.1005       313
#        Health and beauty       12597.7530       257
#        Home and lifestyle      22417.1955       371
#        Sports and travel       19372.6995       333
# B      Electronic accessories  17051.4435       316
#        Fashion accessories     16413.3165       297
#        Food and beverages      15214.8885       270
#        Health and beauty       19980.6600       320
#        Home and lifestyle      17549.1645       295
#        Sports and travel       19988.1990       322
# C      Electronic accessories  18968.9745       333
#        Fashion accessories     21560.0700       342
#        Food and beverages      23766.8550       369
#        Health and beauty       16615.3260       277
#        Home and lifestyle      13895.5530       245
# ...

# %%
grp.sort_values(by=['Total','Quantity'],ascending=[False,False])
# Out:
#                                     Total  Quantity
# Branch Product line
# C      Food and beverages      23766.8550       369
# A      Home and lifestyle      22417.1955       371
# C      Fashion accessories     21560.0700       342
# B      Sports and travel       19988.1990       322
#        Health and beauty       19980.6600       320
# A      Sports and travel       19372.6995       333
# C      Electronic accessories  18968.9745       333
# A      Electronic accessories  18317.1135       322
# B      Home and lifestyle      17549.1645       295
# A      Food and beverages      17163.1005       313
# B      Electronic accessories  17051.4435       316
# C      Health and beauty       16615.3260       277
# B      Fashion accessories     16413.3165       297
# A      Fashion accessories     16332.5085       263
# C      Sports and travel       15761.9280       265
# B      Food and beverages      15214.8885       270
# C      Home and lifestyle      13895.5530       245
# ...

# %%
grp_2 = df.groupby('Branch')
grp_2['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
group = df.groupby('Branch').agg({'Total':'sum','gross income':'mean'})
group.sort_values(by='Total',ascending = False)
# Out:
#               Total  gross income
# Branch
# C       110568.7065     16.052367
# A       106200.3705     14.874001
# B       106197.6720     15.232024

# %% [markdown]
# ## What are the trends in sales overtime?

# %% [markdown]
# ### What time,day,month is sales at its peak?

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
grp4=df.groupby('Day')
grp5=grp4['Quantity'].sum().sort_values(ascending=False)
grp5
# Out:
# Day
# Saturday     919
# Tuesday      862
# Wednesday    800
# Sunday       778
# Friday       758
# Thursday     755
# Monday       638
# Name: Quantity, dtype: int64

# %%
grp6=df.groupby('Month')
grp7=grp6['Quantity'].sum().sort_values(ascending=False)
grp7
# Out:
# Month
# January     1965
# March       1891
# February    1654
# Name: Quantity, dtype: int64

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# Day                                object
# Month                              object
# dtype: object

# %%
df['Hour']= pd.to_datetime(df['Time'], format ='%H:%M:%S').dt.hour

# %%
hourlysales = df.groupby('Time') .agg({'Total':'sum'})
hourlysales.sort_values(by='Total',ascending=False)
# Out:
#               Total
# Time
# 14:42:00  2534.6370
# 13:48:00  2513.0700
# 17:16:00  2324.3745
# 13:00:00  2322.8100
# 15:42:00  2266.4985
# ...             ...
# 15:09:00    26.2500
# 20:47:00    24.1080
# 15:23:00    16.2750
# 11:09:00    16.1070
# 14:11:00    13.4190
#
# [506 rows x 1 columns]

# %%
def categorizetime (hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 23:
        return 'Evening'
    else:
        return 'Midnight'
    
df['Timeperiod']= df['Hour'].apply(categorizetime)   
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  ...  \
# 0         Health and beauty       74.69         7  26.1415   548.9715  ...
# 1    Electronic accessories       15.28         5   3.8200    80.2200  ...
# ...

# %%
periodsales = df.groupby('Timeperiod') .agg({'Total':'sum'})
periodsales.sort_values(by='Total',ascending=False)
# Out:
#                   Total
# Timeperiod
# Afternoon   148023.3405
# Evening     113144.5980
# Morning      61798.8105

# %%
salesovertime = df.groupby('Date').agg({'Total':'sum'}).reset_index()

plt.figure(figsize=(12,6))
plt.plot(salesovertime['Date'],salesovertime['Total'],marker='o')
plt.title('Sales Performance Over Time')
plt.xlabel('Date')
plt.ylabel('Total')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Sales By Payment Method

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
Payment = df.groupby('Payment')['Total'].sum().reset_index()
plt.figure(figsize=(10,6))

plt.pie(Payment['Total'],labels=Payment['Payment'],autopct='%1.1f%%',startangle=140)
plt.title('Sales By Payment Method')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Customer Analysis

# %% [markdown]
# ## Who are the most Valuable customers?

# %% [markdown]
# ### What is the average revenue per customer type?

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  ...  \
# 0         Health and beauty       74.69         7  26.1415   548.9715  ...
# 1    Electronic accessories       15.28         5   3.8200    80.2200  ...
# ...

# %%
revenuecustomer= df.groupby('Customer type')

# %%
revenuecustomer['Total'].mean()
# Out:
# Customer type
# Member    327.791305
# Normal    318.122856
# Name: Total, dtype: float64

# %% [markdown]
# ### How do sales vary by customer gender

# %%
grp2= df.groupby(['Gender','Product line']).agg({'Total':'sum'})
grp2
# Out:
#                                     Total
# Gender Product line
# Female Electronic accessories  27102.0225
#        Fashion accessories     30437.4000
#        Food and beverages      33170.9175
#        Health and beauty       18560.9865
#        Home and lifestyle      30036.8775
#        Sports and travel       28574.7210
# Male   Electronic accessories  27235.5090
#        Fashion accessories     23868.4950
#        Food and beverages      22973.9265
#        Health and beauty       30632.7525
#        Home and lifestyle      23825.0355
#        Sports and travel       26548.1055

# %%
grp2.sort_values(by='Total',ascending=False)
# Out:
#                                     Total
# Gender Product line
# Female Food and beverages      33170.9175
# Male   Health and beauty       30632.7525
# Female Fashion accessories     30437.4000
#        Home and lifestyle      30036.8775
#        Sports and travel       28574.7210
# Male   Electronic accessories  27235.5090
# Female Electronic accessories  27102.0225
# Male   Sports and travel       26548.1055
#        Fashion accessories     23868.4950
#        Home and lifestyle      23825.0355
#        Food and beverages      22973.9265
# Female Health and beauty       18560.9865

# %%
df.groupby(['Gender','Product line']).agg({'Quantity':'sum'}).sort_values(by='Quantity',ascending=False)
# Out:
#                                Quantity
# Gender Product line
# Female Fashion accessories          530
#        Food and beverages           514
# Male   Health and beauty            511
# Female Home and lifestyle           498
#        Sports and travel            496
#        Electronic accessories       488
# Male   Electronic accessories       483
#        Food and beverages           438
#        Sports and travel            424
#        Home and lifestyle           413
#        Fashion accessories          372
# Female Health and beauty            343

# %% [markdown]
# ## How do customer ratings correlate with sales performance?

# %% [markdown]
# ### Do higher rated products generate more sales?

# %%
product_performance = df.groupby('Product line').agg({'Total':'sum','Rating':'mean'})
product_performance.sort_values(by='Total',ascending=False)
# Out:
#                              Total    Rating
# Product line
# Food and beverages      56144.8440  7.113218
# Sports and travel       55122.8265  6.916265
# Electronic accessories  54337.5315  6.924706
# Fashion accessories     54305.8950  7.029213
# Home and lifestyle      53861.9130  6.837500
# Health and beauty       49193.7390  7.003289

# %%
pp= product_performance['Total'].corr(product_performance['Rating'])
print('Correlation between total and ratings: ')
print (pp)
# Out:
# Correlation between total and ratings:
# 0.0924775413951433

# %%
plt.figure(figsize=(12,6))
plt.hist(df['Rating'],bins=10,color='purple',edgecolor='black')
plt.title('Distribution of Customer Ratings')
plt.xlabel('Customer Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Identify Relationships between different variables

# %%
##multivariate analysis
##create a pairplot to visualize relationships between multiple variables
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,vars=['Total','Rating','Unit price','Quantity'],kind='reg')
plt.show()

# %%
correlation = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation,annot=True,cmap='gist_heat',linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Product Analysis

# %% [markdown]
# ### What is the impact of pricing on sales volume?

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  ...  \
# 0         Health and beauty       74.69         7  26.1415   548.9715  ...
# 1    Electronic accessories       15.28         5   3.8200    80.2200  ...
# ...

# %%
import matplotlib.pyplot as plt

df['Unit price'].corr(df['Quantity'])
# Out:
# 0.010777564342497298

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Unit price',y = 'Quantity')
plt.title('Relationship between unit price and quantity sold')
plt.xlabel('Unit price')
plt.ylabel('Quantity sold')
##Fit and plot regression line,
sns.regplot(data= df,scatter=False,color='red',x='Unit price',y = 'Quantity')
plt.show()

# %% [markdown]
# ## Which product have the highest gross margins?

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  ...  \
# 0         Health and beauty       74.69         7  26.1415   548.9715  ...
# 1    Electronic accessories       15.28         5   3.8200    80.2200  ...
# ...

# %% [markdown]
# ## Which Product line are the most profitable and least profitable?

# %% [markdown]
# ### Most and least profitable product lines?

# %%
profit_product = df.groupby('Product line')['gross income'].sum().reset_index()
plt.figure(figsize=(12,6))
plt.bar(profit_product['Product line'],profit_product['gross income'],color='green')
plt.title('Profit By Product Line')
plt.xlabel('Product Line')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Top selling product line by revenue and volume

# %%
toprevenue = df.groupby('Product line').agg({'Total':'sum'}).reset_index()
toprevenue.sort_values(by=['Total'],ascending=[False])


plt.figure(figsize=(12,6))
plt.bar(toprevenue['Product line'],toprevenue['Total'],color='coral')
plt.title('Top Selling Products by Revenue')
plt.xlabel('Product line')
plt.ylabel('Total')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
topvolume = df.groupby('Product line').agg({'Quantity':'sum'}).reset_index()
topvolume.sort_values(by=['Quantity'],ascending=[False])
plt.figure(figsize=(12,6))
plt.bar(topvolume['Product line'],topvolume['Quantity'],color='orange')
plt.title('Top Selling Products by Volume')
plt.xlabel('Product line')
plt.ylabel('Quantity Sold')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
